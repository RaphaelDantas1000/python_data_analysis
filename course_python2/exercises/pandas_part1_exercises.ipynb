# %% [markdown]
# Pandas Part 1 — Exercises

# %% [markdown]
# Section 1 — Insurance Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# 1) Import the data and check the first few rows of the dataset. Also check the last few rows of the dataset.

# %%
df = pd.read_csv("../data/insurance.csv")
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# 2) Check if there are any missing values ​​in the dataset.

# %%
df.isnull().values.any()
# Out:
# np.False_

# %% [markdown]
# 3) How much memory is the dataset consuming?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# 4) Generate descriptive statistics for the numerical columns of the dataset. What is the median of the BMI column? And the mean? Which of these values ​​is larger? What does this mean?

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Q4 - mean=30.663397
# median = 30.400000
#
# Mean BMI is slightly greater than the median BMI which means there are some higher BMI values pulling the average up

# %% [markdown]
# 5) What is the proportion of smokers in our dataset? And of non-smokers?

# %%
df["smoker"].value_counts(normalize=True)*100
# Out:
# smoker
# no     79.521674
# yes    20.478326
# Name: proportion, dtype: float64

# %% [markdown]
# 6) Is there any difference in the charges for smokers and non-smokers? If so, what do you think is the reason for this?

# %%
df.groupby("smoker")["charges"].mean()
# Out:
# smoker
# no      8434.268298
# yes    32050.231832
# Name: charges, dtype: float64

# %% [markdown]
# ## Q6 - Smokers have substantially higher average charges, likely because smoking increases health risks and expected medical costs, which raises insurance pricing.

# %% [markdown]
# 7) What is the average BMI for smokers? Is it very different from that observed for non-smokers? If so, why do you think this is the case?

# %%
df.groupby("smoker")["bmi"].mean()
# Out:
# smoker
# no     30.651795
# yes    30.708449
# Name: bmi, dtype: float64

# %% [markdown]
# ## Q7 - BMI is very similar between smokers and non-smokers

# %% [markdown]
# 8) Is there any difference in charges for those who have children? Identify if having children seems to result in higher charges by looking at the average charges for those with 0 children and the average for those with 1 or more children.

# %%
df.groupby("children")["charges"].mean()
# Out:
# children
# 0    12365.975602
# 1    12731.171832
# 2    15073.563734
# 3    15355.318367
# 4    13850.656311
# 5     8786.035247
# Name: charges, dtype: float64

# %% [markdown]
# ## Q8 - Individuals with at least one child show higher average charges than those without children, possibly because families tend to use more healthcare services, increasing total insurance costs.

# %% [markdown]
# 9) For men, a BMI of 20 to 24.9 is considered normal. Above that, it is considered overweight, and below it is considered underweight. Create a new column called "bmi_male" that will receive the text "below normal" for BMI below 20, "normal" for BMI from 20 to 24.9, and "above normal" for BMI above 24.9.

# %%
conditions = [
    (df["sex"] == "male") & (df["bmi"] < 20),
    (df["sex"] == "male") & (df["bmi"] >= 20) & (df["bmi"] <= 24.9),
    (df["sex"] == "male") & (df["bmi"] > 24.9)
]

choices = ["below normal", "normal", "above normal"]

df["bmi_male"] = np.select(conditions, choices, default="not male")

# %% [markdown]
# 10) If a man is a smoker and still has a BMI above what is considered normal, this could be a negative indicator for the insurance company. How many men are in this situation?

# %%
df[(df["sex"] == "male") & (df["smoker"] == "yes") & (df["bmi_male"] == "above normal")].shape[0]
# Out:
# 136

# %% [markdown]
# ## Q10 - There are 136 men in this situation.

# %% [markdown]
# Section 2 - Forest Fires Dataset

# %% [markdown]
# 11) Load the dataset and create a message for the notebook reader stating how many rows and columns the DataFrame has.

# %%
df = pd.read_csv("../data/amazon.csv", encoding="latin-1")
df.shape
# Out:
# (6454, 5)

# %% [markdown]
# ## Q11 - The dataset has 6454 rows and 5 columns

# %% [markdown]
# 12) Use loc and iloc to display rows 100 through 120 of the second, third, and fourth columns. What is the difference between the two syntaxes?

# %%
df.iloc[100:121, 2:5]
# Out:
#      month  number        date
# 100  Junho     3.0  1998-01-01
# 101  Junho     0.0  1999-01-01
# 102  Junho     1.0  2000-01-01
# 103  Junho     1.0  2001-01-01
# 104  Junho     0.0  2002-01-01
# 105  Junho     0.0  2003-01-01
# 106  Junho     5.0  2004-01-01
# 107  Junho    27.0  2005-01-01
# 108  Junho     1.0  2006-01-01
# 109  Junho     4.0  2007-01-01
# 110  Junho     0.0  2008-01-01
# 111  Junho     0.0  2009-01-01
# 112  Junho     1.0  2010-01-01
# 113  Junho    10.0  2011-01-01
# 114  Junho     7.0  2012-01-01
# 115  Junho     8.0  2013-01-01
# 116  Junho    17.0  2014-01-01
# 117  Junho    40.0  2015-01-01
# 118  Junho    87.0  2016-01-01
# 119  Junho    45.0  2017-01-01
# 120  Julho    37.0  1998-01-01

# %%
df.loc[100:120,["state","month","number"]]
# Out:
#     state  month  number
# 100  Acre  Junho     3.0
# 101  Acre  Junho     0.0
# 102  Acre  Junho     1.0
# 103  Acre  Junho     1.0
# 104  Acre  Junho     0.0
# 105  Acre  Junho     0.0
# 106  Acre  Junho     5.0
# 107  Acre  Junho    27.0
# 108  Acre  Junho     1.0
# 109  Acre  Junho     4.0
# 110  Acre  Junho     0.0
# 111  Acre  Junho     0.0
# 112  Acre  Junho     1.0
# 113  Acre  Junho    10.0
# 114  Acre  Junho     7.0
# 115  Acre  Junho     8.0
# 116  Acre  Junho    17.0
# 117  Acre  Junho    40.0
# 118  Acre  Junho    87.0
# 119  Acre  Junho    45.0
# 120  Acre  Julho    37.0

# %% [markdown]
# ## Q12 - iloc selects rows and columns by numerical position, while loc selects them by index labels or column names. Additionally, iloc slicing excludes the end position, whereas loc slicing includes the end label.

# %% [markdown]
# 13) What was the total number of fires that occurred in Brazil in 2010? And what if we consider only the state of Mato Grosso?

# %%
df[df["year"] == 2010]["number"].sum()
# Out:
# np.float64(37037.449)

# %%
df[(df["year"] == 2010) & (df["state"] == "Mato Grosso")]["number"].sum()
# Out:
# np.float64(6252.445)

# %% [markdown]
# ## Q13 - In 2010, Brazil recorded 37,037 fires, of which 6,252 occurred in the state of Mato Grosso.
